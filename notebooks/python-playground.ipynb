# %%
# %gui qt
import matplotlib.pyplot as plt
from skimage.filters import threshold_local, threshold_isodata, gaussian, try_all_threshold, threshold_yen
from skimage.io import imread, imshow
from skimage import exposure
from skimage.segmentation import watershed
from skimage.feature import peak_local_max
from skimage.feature import blob_dog, blob_log, blob_doh
import numpy as np
from scipy import ndimage as ndi
import matplotlib
import matplotlib.pyplot as plt
import napari

# %%
filename  = "/Users/mrestrep/projects/borton/calacium_images/example_data/Preprocessedfiles/MAX_6_2_2_24_10x_4minadjust_isa.tif"
raw = imread(filename)
imshow(raw)

# %%
gaussian_image = gaussian(raw*50, sigma = 2.5)
imshow(gaussian_image)

# %%
try_all_threshold(raw)
# Out:
# skimage.filters.thresholding.threshold_isodata
# skimage.filters.thresholding.threshold_li
# skimage.filters.thresholding.threshold_mean
# skimage.filters.thresholding.threshold_minimum
# skimage.filters.thresholding.threshold_otsu
# skimage.filters.thresholding.threshold_triangle
# skimage.filters.thresholding.threshold_yen
# (<Figure size 576x360 with 8 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x132c08280>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132bfdd60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132c42940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132c727c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132ca2640>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132cd5580>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132cf7430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132d044c0>],
#        dtype=object))

# %%
lt = threshold_local(gaussian_image, 5, method = 'mean')
binary_lt = gaussian_image > lt + (lt*.02)
imshow(binary_lt)

# %%
distance = ndi.distance_transform_edt(binary_lt)
local_maxi = peak_local_max(distance, indices=False, footprint=np.ones((3, 3)),
                            labels=binary_lt)
markers = ndi.label(local_maxi)[0]
labels = watershed(-distance, markers, mask=binary_lt)

# %%
nc = len(np.unique(labels))
cmap = matplotlib.colors.ListedColormap ( np.random.rand (nc,3))

# %%
imshow(labels, cmap=cmap)

# %%
imshow(distance, cmap=plt.cm.gray)

# %%
imshow(local_maxi)

# %%
blobs_log = blob_log(distance, min_sigma=1, max_sigma=5, threshold=0.03, overlap=0.5, exclude_border=1)

# %%
# create the viewer with an image
viewer = napari.view_image(distance, rgb=False)
viewer.add_image(gaussian_image, rgb=False)
viewer.add_points(blobs_log[:, 0:2],
                    edge_width=1,
                    edge_color='coral',
                    face_color='royalblue',
                    name='points',
                    size=blobs_log[:,2])
# Out:
# <Points layer 'points' at 0x138b36e50>

# %%
blobs_log
# Out:
# array([[280.        , 277.        ,   1.88888889],
#        [256.        , 294.        ,   1.88888889],
#        [285.        , 300.        ,   2.33333333],
#        [ 52.        , 245.        ,   1.88888889],
#        [220.        , 247.        ,   1.88888889],
#        [190.        , 355.        ,   2.33333333],
#        [308.        , 147.        ,   1.88888889],
#        [280.        , 333.        ,   2.33333333],
#        [281.        , 358.        ,   1.88888889],
#        [190.        , 162.        ,   1.88888889],
#        [180.        , 247.        ,   1.88888889],
#        [165.        , 163.        ,   1.88888889],
#        [377.        , 182.        ,   1.88888889],
#        [246.        , 274.        ,   1.88888889],
#        [241.        , 370.        ,   1.88888889],
#        [367.        , 107.        ,   1.88888889],
#        [146.        , 258.        ,   1.88888889],
#        [444.        , 280.        ,   2.33333333],
#        [229.        , 415.        ,   1.88888889],
#        [209.        , 298.        ,   1.88888889],
#        [117.        , 247.        ,   1.88888889],
